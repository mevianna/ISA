# %% [markdown]
# 3.1 IDENTIFICAÇÃO DE PROBLEMAS NOS DADOS
#
#     Os cuidados que devem ser tomados na construção de uma base de dados varia conforme o nível de abstração da linguagem que esta usando. Com isso em mente para os exemplos a seguir vou utilizar da linguagem de alto nível, o python. Primeiro é preciso saber identificar o tipo de problema para depois tratá-lo, por exemplo com valores ausentes.
#     Valores ausentes
#     Dados duplicados
#     Tipos de dados incorretos
#     Valores inconcistentes

# %%
#codigo exemplo em python valores ausentes

# %% [markdown]
# REFERÊNCIAS:
#
# [1]MCKINNEY, Wes. Python para análise de dados: Tratamento de dados com Pandas, NumPy e IPython. Novatec Editora, 2018.
# [2]EHRLINGER, Lisa; WÖß, Wolfram. A survey of data quality measurement and monitoring tools. Frontiers in big data, v. 5, p. 850611, 2022.
# [3]SCIKIT-LEARN. 8.4. Imputation of missing values. In: SCIKIT-LEARN. Documentation. Versão 1.9.1. [S. l.]: scikit-learn, 2026. Disponível em: https://scikit-learn.org/stable/modules/impute.html. Acesso em: 20 set. 2026.
